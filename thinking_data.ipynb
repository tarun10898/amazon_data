# %%
import json
def load_data(file_name):
    with open(file_name,"r") as f:
        data = json.load(f)
    return data

# %%
data=load_data("data.json")

# %%
print(type(data))
# Out:
# <class 'list'>
